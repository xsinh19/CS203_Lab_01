# %% [markdown]
# # ASSIGNMENT TASK 3 : INTER ANNOTATOR AGREEMENT
# Task 3: Implementing Inter-Annotator Agreement Export the annotations in either JSON or CSV files. Using Python code, calculate Cohen’s Kappa & Fleiss Kappa. Use Cohen’s Kappa for the NLP Dataset Task. Use Fleiss Kappa for the CV Dataset Task. Get the third annotation from any other team and then calculate the Fleiss Kappa. Output the agreement score and interpret its significance.

# %%
import pandas as pd
from sklearn.metrics import cohen_kappa_score

# %% [markdown]
# # Cohen's Kappa for NLP Annotations

# %%
# Load annotations from CSV files
def load_csv_annotations(file_path, label_column): # Process annotations from a csv file
    data = pd.read_csv(file_path)
    extracted_tags = []
    for _, row in data.iterrows():
        try:
            tags = eval(row[label_column])  # Convert stringified lists to Python objects
            tags.sort(key=lambda x: x["start"])  # Sort by the "start" field
            extracted_tags.append([tag["labels"][0] for tag in tags])
        except Exception:
            extracted_tags.append([])  # Handle rows with invalid or missing labels
    return extracted_tags

# Align POS tags between two annotators
def synchronize_csv_annotations(tags_list1, tags_list2): # Synchronize the annotations of two annotators
    aligned_list1 = []
    aligned_list2 = []
    for tags1, tags2 in zip(tags_list1, tags_list2):
        length = min(len(tags1), len(tags2))
        aligned_list1.extend(tags1[:length])
        aligned_list2.extend(tags2[:length])
    return aligned_list1, aligned_list2

# %%
# File paths for the two annotators
csv_file_annotator1 = "het_nlp_csv.csv"
csv_file_annotator2 = "shivraj_nlp_csv.csv"

# Load and process annotations
data_annotator1 = load_csv_annotations(csv_file_annotator1, label_column="label")
data_annotator2 = load_csv_annotations(csv_file_annotator2, label_column="label")

# Synchronize annotations for comparison
aligned_tags_annotator1, aligned_tags_annotator2 = synchronize_csv_annotations(data_annotator1, data_annotator2)

# %%
# Display aligned tags
for index in range(len(aligned_tags_annotator1)):
    print(f'Tag Index: {index} ----> {aligned_tags_annotator1[index]}   :    {aligned_tags_annotator2[index]}')

# Compute Cohen's Kappa score
agreement_score = cohen_kappa_score(aligned_tags_annotator1, aligned_tags_annotator2)

# Display the agreement score
print(f"Cohen's Kappa Score: {agreement_score:.4f}")
# Out:
# Tag Index: 0 ----> PROPN   :    PROPN
# Tag Index: 1 ----> ADP   :    NOUN
# Tag Index: 2 ----> PROPN   :    PROPN
# Tag Index: 3 ----> ADP   :    ADJ
# Tag Index: 4 ----> NUM   :    VERB
# Tag Index: 5 ----> NOUN   :    NOUN
# Tag Index: 6 ----> X   :    X
# Tag Index: 7 ----> X   :    DET
# Tag Index: 8 ----> DET   :    DET
# Tag Index: 9 ----> NOUN   :    NOUN
# Tag Index: 10 ----> PART   :    PART
# Tag Index: 11 ----> PRON_WH   :    PRON_WH
# Tag Index: 12 ----> ADJ   :    ADJ
# Tag Index: 13 ----> NOUN   :    NOUN
# Tag Index: 14 ----> ADP   :    ADJ
# Tag Index: 15 ----> PART   :    PART
# Tag Index: 16 ----> X   :    X
# Tag Index: 17 ----> NUM   :    DET
# Tag Index: 18 ----> CONJ   :    CONJ
# Tag Index: 19 ----> PROPN   :    PROPN
# Tag Index: 20 ----> NOUN   :    NOUN
# Tag Index: 21 ----> PROPN   :    PROPN
# Tag Index: 22 ----> ADP   :    ADP
# Tag Index: 23 ----> VERB   :    VERB
# Tag Index: 24 ----> PRON   :    PRON
# Tag Index: 25 ----> NOUN   :    NOUN
# Tag Index: 26 ----> X   :    X
# Tag Index: 27 ----> PROPN   :    X
# Tag Index: 28 ----> PROPN   :    PROPN
# Tag Index: 29 ----> ADP   :    ADP
# Tag Index: 30 ----> ADJ   :    ADJ
# Tag Index: 31 ----> NOUN   :    NOUN
# Tag Index: 32 ----> ADP   :    ADP
# Tag Index: 33 ----> PROPN   :    PROPN
# Tag Index: 34 ----> ADP   :    ADP
# Tag Index: 35 ----> PROPN   :    PROPN
# Tag Index: 36 ----> ADP   :    ADP
# Tag Index: 37 ----> VERB   :    VERB
# Tag Index: 38 ----> VERB   :    X
# Tag Index: 39 ----> X   :    PROPN
# Tag Index: 40 ----> PROPN   :    PROPN
# Tag Index: 41 ----> ADP   :    ADP
# Tag Index: 42 ----> VERB   :    VERB
# Tag Index: 43 ----> VERB   :    PROPN
# Tag Index: 44 ----> PROPN   :    ADP
# Tag Index: 45 ----> ADP   :    NOUN
# Tag Index: 46 ----> NOUN   :    ADP
# Tag Index: 47 ----> ADP   :    PRON_WH
# Tag Index: 48 ----> PRON_WH   :    VERB
# Tag Index: 49 ----> VERB   :    X
# Tag Index: 50 ----> X   :    PROPN
# Tag Index: 51 ----> NUM   :    DET
# Tag Index: 52 ----> CONJ   :    CONJ
# Tag Index: 53 ----> PROPN   :    PROPN
# Tag Index: 54 ----> NOUN   :    NOUN
# Tag Index: 55 ----> PROPN   :    PROPN
# Tag Index: 56 ----> ADP   :    ADP
# Tag Index: 57 ----> NOUN   :    NOUN
# Tag Index: 58 ----> ADP   :    ADP
# Tag Index: 59 ----> VERB   :    VERB
# Tag Index: 60 ----> PART   :    PRON
# Tag Index: 61 ----> PRON   :    NOUN
# Tag Index: 62 ----> NOUN   :    X
# Tag Index: 63 ----> X   :    PROPN
# Tag Index: 64 ----> PROPN   :    PROPN
# Tag Index: 65 ----> ADP   :    ADP
# Tag Index: 66 ----> PRON_WH   :    PRON
# Tag Index: 67 ----> NOUN   :    NOUN
# Tag Index: 68 ----> ADP   :    ADP
# Tag Index: 69 ----> PROPN   :    PROPN
# Tag Index: 70 ----> ADP   :    ADP
# Tag Index: 71 ----> NOUN   :    NOUN
# Tag Index: 72 ----> VERB   :    VERB
# Tag Index: 73 ----> PART   :    X
# Tag Index: 74 ----> X   :    PROPN
# Tag Index: 75 ----> X   :    CONJ
# Tag Index: 76 ----> PROPN   :    PROPN
# Tag Index: 77 ----> PROPN   :    PROPN
# Tag Index: 78 ----> ADP   :    ADP
# Tag Index: 79 ----> PRON   :    PRON
# Tag Index: 80 ----> PROPN   :    PROPN
# Tag Index: 81 ----> CONJ   :    CONJ
# Tag Index: 82 ----> PROPN   :    PROPN
# Tag Index: 83 ----> ADP   :    ADP
# Tag Index: 84 ----> NOUN   :    NOUN
# Tag Index: 85 ----> VERB   :    VERB
# Tag Index: 86 ----> VERB   :    X
# Tag Index: 87 ----> PART   :    NOUN
# Tag Index: 88 ----> X   :    X
# Tag Index: 89 ----> NOUN   :    PROPN
# Tag Index: 90 ----> PROPN   :    PROPN
# Tag Index: 91 ----> ADP   :    ADP
# Tag Index: 92 ----> NOUN   :    NOUN
# Tag Index: 93 ----> ADP   :    ADP
# Tag Index: 94 ----> PROPN   :    PROPN
# Tag Index: 95 ----> ADP   :    ADP
# Tag Index: 96 ----> PRON_WH   :    PRON_WH
# Tag Index: 97 ----> VERB   :    VERB
# Tag Index: 98 ----> PART   :    X
# Tag Index: 99 ----> PROPN   :    PROPN
# Tag Index: 100 ----> ADP   :    ADJ
# Tag Index: 101 ----> PROPN   :    NOUN
# Tag Index: 102 ----> ADP   :    ADJ
# Tag Index: 103 ----> PROPN   :    PROPN
# Tag Index: 104 ----> ADP   :    ADP
# Tag Index: 105 ----> VERB   :    VERB
# Tag Index: 106 ----> NOUN   :    NOUN
# Tag Index: 107 ----> X   :    X
# Tag Index: 108 ----> PROPN   :    PROPN
# Tag Index: 109 ----> PRON   :    NOUN
# Tag Index: 110 ----> ADP   :    ADP
# Tag Index: 111 ----> VERB   :    VERB
# Tag Index: 112 ----> PART   :    NOUN
# Tag Index: 113 ----> NOUN   :    X
# Tag Index: 114 ----> NOUN   :    PROPN
# Tag Index: 115 ----> PROPN   :    NOUN
# Tag Index: 116 ----> ADP   :    ADP
# Tag Index: 117 ----> PROPN   :    NOUN
# Tag Index: 118 ----> ADP   :    ADP
# Tag Index: 119 ----> PROPN   :    NOUN
# Tag Index: 120 ----> ADP   :    ADP
# Tag Index: 121 ----> ADJ   :    ADV
# Tag Index: 122 ----> NOUN   :    PROPN
# Tag Index: 123 ----> ADP   :    ADP
# Tag Index: 124 ----> VERB   :    VERB
# Tag Index: 125 ----> NOUN   :    NOUN
# Tag Index: 126 ----> PROPN   :    PROPN
# Tag Index: 127 ----> ADP   :    ADP
# Tag Index: 128 ----> PROPN   :    PROPN
# Tag Index: 129 ----> ADP   :    ADP
# Tag Index: 130 ----> NOUN   :    NOUN
# Tag Index: 131 ----> ADP   :    ADP
# Tag Index: 132 ----> VERB   :    VERB
# Tag Index: 133 ----> ADJ   :    ADJ
# Tag Index: 134 ----> NOUN   :    NOUN
# Tag Index: 135 ----> ADP   :    ADP
# Tag Index: 136 ----> PART   :    VERB
# Tag Index: 137 ----> ADP   :    X
# Tag Index: 138 ----> PROPN   :    PROPN
# Tag Index: 139 ----> X   :    X
# Tag Index: 140 ----> PROPN   :    PROPN
# Tag Index: 141 ----> ADP   :    ADP
# Tag Index: 142 ----> PROPN   :    PROPN
# Tag Index: 143 ----> ADP   :    ADP
# Tag Index: 144 ----> VERB   :    VERB
# Tag Index: 145 ----> X   :    X
# Tag Index: 146 ----> ADP   :    ADP
# Tag Index: 147 ----> NOUN   :    NOUN
# Tag Index: 148 ----> X   :    X
# Tag Index: 149 ----> PROPN   :    PROPN
# Tag Index: 150 ----> ADP   :    ADP
# Tag Index: 151 ----> PROPN   :    PROPN
# Tag Index: 152 ----> NOUN   :    NOUN
# Tag Index: 153 ----> PROPN   :    PROPN
# Tag Index: 154 ----> ADJ   :    ADP
# Tag Index: 155 ----> VERB   :    VERB
# Tag Index: 156 ----> ADJ   :    ADJ
# Tag Index: 157 ----> NOUN   :    NOUN
# Tag Index: 158 ----> X   :    X
# Tag Index: 159 ----> X   :    VERB
# Tag Index: 160 ----> VERB   :    PART
# Tag Index: 161 ----> PART   :    ADJ
# Tag Index: 162 ----> ADJ   :    VERB
# Tag Index: 163 ----> VERB   :    PRON
# Tag Index: 164 ----> PROPN   :    PROPN
# Tag Index: 165 ----> ADP   :    ADP
# Tag Index: 166 ----> PROPN   :    X
# Tag Index: 167 ----> ADP   :    X
# Tag Index: 168 ----> NOUN   :    X
# Tag Index: 169 ----> ADP   :    ADP
# Tag Index: 170 ----> NOUN   :    NOUN
# Tag Index: 171 ----> ADP   :    ADP
# Tag Index: 172 ----> PROPN   :    NOUN
# Tag Index: 173 ----> ADP   :    ADP
# Tag Index: 174 ----> ADJ   :    PROPN
# Tag Index: 175 ----> ADJ   :    ADP
# Tag Index: 176 ----> NOUN   :    ADJ
# Tag Index: 177 ----> X   :    ADJ
# Tag Index: 178 ----> X   :    NOUN
# Tag Index: 179 ----> PROPN   :    X
# Tag Index: 180 ----> PROPN   :    PROPN
# Tag Index: 181 ----> PROPN   :    PROPN
# Tag Index: 182 ----> ADP   :    ADP
# Tag Index: 183 ----> PROPN   :    PROPN
# Tag Index: 184 ----> CONJ   :    CONJ
# Tag Index: 185 ----> NOUN   :    PROPN
# Tag Index: 186 ----> PROPN   :    ADP
# Tag Index: 187 ----> ADP   :    NOUN
# Tag Index: 188 ----> NOUN   :    X
# Tag Index: 189 ----> X   :    PROPN
# Tag Index: 190 ----> PROPN   :    PROPN
# Tag Index: 191 ----> CONJ   :    CONJ
# Tag Index: 192 ----> NOUN   :    PROPN
# Tag Index: 193 ----> PROPN   :    ADP
# Tag Index: 194 ----> ADP   :    PROPN
# Tag Index: 195 ----> PROPN   :    ADP
# Tag Index: 196 ----> ADP   :    VERB
# Tag Index: 197 ----> VERB   :    X
# Tag Index: 198 ----> ADP   :    PROPN
# Tag Index: 199 ----> PROPN   :    X
# Tag Index: 200 ----> X   :    PROPN
# Tag Index: 201 ----> PROPN   :    PROPN
# Tag Index: 202 ----> CONJ   :    CONJ
# Tag Index: 203 ----> PROPN   :    PROPN
# Tag Index: 204 ----> ADP   :    ADP
# Tag Index: 205 ----> ADJ   :    ADV
# Tag Index: 206 ----> VERB   :    VERB
# Tag Index: 207 ----> X   :    X
# Tag Index: 208 ----> ADP   :    ADP
# Tag Index: 209 ----> NOUN   :    NOUN
# Tag Index: 210 ----> ADP   :    ADP
# Tag Index: 211 ----> X   :    X
# Tag Index: 212 ----> ADP   :    ADP
# Tag Index: 213 ----> NOUN   :    NOUN
# Tag Index: 214 ----> VERB   :    VERB
# Tag Index: 215 ----> X   :    X
# Tag Index: 216 ----> PROPN   :    PROPN
# Tag Index: 217 ----> NOUN   :    ADP
# Tag Index: 218 ----> ADP   :    PROPN
# Tag Index: 219 ----> PROPN   :    ADP
# Tag Index: 220 ----> ADP   :    NOUN
# Tag Index: 221 ----> NOUN   :    X
# Tag Index: 222 ----> X   :    ADJ
# Tag Index: 223 ----> ADJ   :    NOUN
# Tag Index: 224 ----> NOUN   :    X
# Tag Index: 225 ----> X   :    NOUN
# Tag Index: 226 ----> NOUN   :    CONJ
# Tag Index: 227 ----> CONJ   :    PROPN
# Tag Index: 228 ----> NOUN   :    VERB
# Tag Index: 229 ----> VERB   :    X
# Tag Index: 230 ----> NOUN   :    PROPN
# Tag Index: 231 ----> PROPN   :    ADP
# Tag Index: 232 ----> ADP   :    VERB
# Tag Index: 233 ----> ADP   :    PROPN
# Tag Index: 234 ----> PROPN   :    NOUN
# Tag Index: 235 ----> NOUN   :    PROPN
# Tag Index: 236 ----> PROPN   :    ADP
# Tag Index: 237 ----> ADP   :    VERB
# Tag Index: 238 ----> VERB   :    X
# Tag Index: 239 ----> VERB   :    VERB
# Tag Index: 240 ----> X   :    ADJ
# Tag Index: 241 ----> VERB   :    NOUN
# Tag Index: 242 ----> ADJ   :    X
# Tag Index: 243 ----> NOUN   :    PROPN
# Tag Index: 244 ----> PROPN   :    PROPN
# Tag Index: 245 ----> CONJ   :    CONJ
# Tag Index: 246 ----> PROPN   :    PROPN
# Tag Index: 247 ----> VERB   :    VERB
# Tag Index: 248 ----> PART   :    PART
# Tag Index: 249 ----> NOUN   :    NOUN
# Tag Index: 250 ----> ADP   :    ADP
# Tag Index: 251 ----> VERB   :    VERB
# Tag Index: 252 ----> PART   :    X
# Cohen's Kappa Score: 0.5223

# %%
# Interpret the agreement score
if agreement_score > 0.8:
    score_interpretation = "Almost Perfect Agreement"
elif agreement_score > 0.6:
    score_interpretation = "Substantial Agreement"
elif agreement_score > 0.4:
    score_interpretation = "Moderate Agreement"
elif agreement_score > 0.2:
    score_interpretation = "Fair Agreement"
elif agreement_score > 0:
    score_interpretation = "Slight Agreement"
else:
    score_interpretation = "No Agreement"

print(f"Interpretation: {score_interpretation}")
# Out:
# Interpretation: Moderate Agreement

# %% [markdown]
# *  The range of moderate agreement (0.41–0.60) is represented by a Cohen's Kappa score of 0.5223.
# *  This suggests that there is some degree of discrepancy in the annotations made by the two annotators, despite their reasonable level of agreement.
# *  This score indicates that although the annotators agree on a large number of judgments (in this case, POS tagging), there are some points of contention, and the annotation procedures or standards would require more work to reach greater agreement.

# %% [markdown]
# # Fleiss's Kappa for CV Annotations

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.inter_rater import fleiss_kappa
from collections import defaultdict
import statsmodels

# %%
# Paths to the CSV files (assumed to contain annotations from different annotators)
csv_files = ['het_cv_csv.csv', 'shivraj_cv_csv.csv', 'TEAM2_cv_csv.csv']

def compute_fleiss_kappa(csv_files, label_column="label", image_column="image"): # Fleiss Kappa for inter annotator agreement
    # Container to store annotations from all annotators
    annotation_matrix = []

    # Process each annotator's CSV file
    for idx, file_path in enumerate(csv_files):
        with open(file_path, 'r') as file:
            # Load the CSV file into a DataFrame
            data = pd.read_csv(file)

            # Extract the labels for classification
            annotations = list(data[label_column])
            annotation_matrix.append(annotations)

    # Display aligned annotations for each image
    for i in range(len(annotation_matrix[0])):
        print(f"Image {i+1}: Annotator 1 -> {annotation_matrix[0][i]}, Annotator 2 -> {annotation_matrix[1][i]}, Annotator 3 -> {annotation_matrix[2][i]}")

    # Aggregate annotations to a table format suitable for Fleiss' Kappa
    fleiss_table = statsmodels.stats.inter_rater.aggregate_raters(annotation_matrix)
    print("Fleiss Table:\n", fleiss_table)

    # Compute Fleiss' Kappa score
    kappa_score = statsmodels.stats.inter_rater.fleiss_kappa(fleiss_table[0], method='fleiss')
    return kappa_score


# Compute Fleiss' Kappa score for the given CSV files
fleiss_kappa_result = compute_fleiss_kappa(csv_files)

# Output the Fleiss' Kappa score
print(f"Fleiss' Kappa Score: {fleiss_kappa_result:.4f}")
# Out:
# Image 1: Annotator 1 -> Truck, Annotator 2 -> No Truck, Annotator 3 -> No Truck
# Image 2: Annotator 1 -> Truck, Annotator 2 -> No Truck, Annotator 3 -> No Truck
# Image 3: Annotator 1 -> No Truck, Annotator 2 -> No Truck, Annotator 3 -> Truck
# Image 4: Annotator 1 -> No Truck, Annotator 2 -> Truck, Annotator 3 -> No Truck
# Image 5: Annotator 1 -> Truck, Annotator 2 -> No Truck, Annotator 3 -> No Truck
# Image 6: Annotator 1 -> Truck, Annotator 2 -> No Truck, Annotator 3 -> No Truck
# Image 7: Annotator 1 -> No Truck, Annotator 2 -> Truck, Annotator 3 -> No Truck
# Image 8: Annotator 1 -> Truck, Annotator 2 -> No Truck, Annotator 3 -> Truck
# Image 9: Annotator 1 -> Truck, Annotator 2 -> Truck, Annotator 3 -> No Truck
# Image 10: Annotator 1 -> No Truck, Annotator 2 -> Truck, Annotator 3 -> No Truck
# Image 11: Annotator 1 -> Truck, Annotator 2 -> Truck, Annotator 3 -> Truck
# Image 12: Annotator 1 -> Truck, Annotator 2 -> Truck, Annotator 3 -> Truck
# Image 13: Annotator 1 -> Truck, Annotator 2 -> Truck, Annotator 3 -> No Truck
# Image 14: Annotator 1 -> Truck, Annotator 2 -> No Truck, Annotator 3 -> No Truck
# Image 15: Annotator 1 -> No Truck, Annotator 2 -> No Truck, Annotator 3 -> No Truck
# Image 16: Annotator 1 -> No Truck, Annotator 2 -> Truck, Annotator 3 -> No Truck
# Image 17: Annotator 1 -> Truck, Annotator 2 -> Truck, Annotator 3 -> Truck
# Image 18: Annotator 1 -> No Truck, Annotator 2 -> Truck, Annotator 3 -> No Truck
# Image 19: Annotator 1 -> No Truck, Annotator 2 -> Truck, Annotator 3 -> Truck
# Image 20: Annotator 1 -> No Truck, Annotator 2 -> Truck, Annotator 3 -> No Truck
# Fleiss Table:
#  (array([[ 9, 11],
#        [ 8, 12],
#        [14,  6]]), array(['No Truck', 'Truck'], dtype='<U8'))
# Fleiss' Kappa Score: 0.0200

# %% [markdown]
# *  Poor agreement (almost "No Agreement") is indicated by a Fleiss' Kappa score of 0.0200.
# *  According to this score, there is little consistency in the annotators' classifications of photos as "Truck" or "No Truck," indicating that they differ greatly.
# *  The low level of agreement could result from:
# 1. Ambiguity in the dataset: Annotators may interpret certain photographs differently if they don't clearly show a truck within a reasonable distance or none at all.
# 2. Absence of explicit annotation guidelines: It's possible that the annotators used different labeling standards, due to the vague definition of a "Truck". Some heavy vehicles carrying loads like a tempo might be viewed by some as a truck.
